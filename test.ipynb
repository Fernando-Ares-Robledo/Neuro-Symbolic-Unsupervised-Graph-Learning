# %% [markdown]
# Test framework

# %%
from imports import *

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from networkx.algorithms import community  

import time
import config
from utiles import record_memory_usage
from imports import * 

# ─────────────────────────────────────────────────────────────────────────────
# 0) Reiniciar 
# ─────────────────────────────────────────────────────────────────────────────
config.memory_times  = []
config.memory_values = []
config.start_time    = time.time()

# ─────────────────────────────────────────────────────────────────────────────
# 1)  dataframe
# ─────────────────────────────────────────────────────────────────────────────
df = pd.read_csv("../IoT Network Intrusion Dataset.csv")
record_memory_usage(label="after_load", record_every=1, iteration=0)

df = df.drop(columns=[
    'Flow_ID', 'Cat', 'Sub_Cat', 'Timestamp',
    'Src_IP', 'Dst_IP', 'Label'
])
record_memory_usage(label="after_drop_cols", record_every=1, iteration=1)

df_sample = df.sample(n=70000, random_state=42)
df_sample.replace([np.inf, -np.inf], np.nan, inplace=True)
df_sample.dropna(inplace=True)
record_memory_usage(label="after_sample_clean", record_every=1, iteration=2)

# ─────────────────────────────────────────────────────────────────────────────
# 2) Transposición y similitud
# ─────────────────────────────────────────────────────────────────────────────
df_transposed = df_sample.transpose()
record_memory_usage(label="after_transpose", record_every=1, iteration=3)

similarity_matrix = cosine_similarity(df_transposed)
record_memory_usage(label="after_cosine", record_every=1, iteration=4)

# ─────────────────────────────────────────────────────────────────────────────
# 3) grafo 
# ─────────────────────────────────────────────────────────────────────────────
threshold = 0.99
features  = list(df_transposed.index)

G = nx.Graph()
G.add_nodes_from(features)
record_memory_usage(label="after_add_nodes", record_every=1, iteration=5)

for i in range(len(features)):
    for j in range(i + 1, len(features)):
        if similarity_matrix[i, j] >= threshold:
            G.add_edge(features[i], features[j], weight=similarity_matrix[i, j])
    record_memory_usage(label="edge_build", record_every=500, iteration=i)

t_fs_end = time.time() - config.start_time
print(f"Feature selection done in {t_fs_end:.1f}s")

# ─────────────────────────────────────────────────────────────────────────────
# 4) comunidades
# ─────────────────────────────────────────────────────────────────────────────
communities = community.greedy_modularity_communities(G)
record_memory_usage(label="after_communities", record_every=1, iteration=0)

selected_features = []
for idx, comm in enumerate(communities):
    if len(comm) > 1:
        subg = G.subgraph(comm)
        cent = nx.degree_centrality(subg)
        rep = max(cent, key=cent.get)
        selected_features.append(rep)
    else:
        selected_features.extend(comm)
    record_memory_usage(label="centrality", record_every=5, iteration=idx)

t_fs_end2 = time.time() - config.start_time
print(f"Community & repr. selection done in {t_fs_end2:.1f}s")

# ─────────────────────────────────────────────────────────────────────────────
# 5) plot
# ─────────────────────────────────────────────────────────────────────────────
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G)
colors = ["red" if n in selected_features else "skyblue" for n in G]
nx.draw_networkx(
    G, pos,
    node_color=colors, node_size=50,
    with_labels=False, edge_color="gray"
)
plt.title("Graph-Based Feature Selection")
plt.axis("off")
record_memory_usage(label="after_plot", record_every=1, iteration=0)

# ─────────────────────────────────────────────────────────────────────────────
# 6) DataFrame final
# ─────────────────────────────────────────────────────────────────────────────
all_feats       = set(G.nodes())
unselected      = all_feats - set(selected_features)
df_final        = pd.read_csv("../IoT Network Intrusion Dataset.csv")
df_final        = df_final.drop(columns=list(unselected))
record_memory_usage(label="after_final_drop", record_every=1, iteration=0)

t_fs_complete = time.time() - config.start_time
print(f"Total feature selection phase in {t_fs_complete:.1f}s")

# %%
import optuna
import torch
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.metrics import matthews_corrcoef
from data import *
from dataset import *
from neural import *
from symbolic import *
from trainer import *

df=df_final
#df= df[0:100]
time.sleep(0.1) 
t_fs_complete = time.time() - config.start_time

# ————————————————————————————————————————————————————————————————
# --- FASE 1: Crear grafos directos ---------------
graphs_info = create_graphs_from_dataset(df, record_every=100)
t_directos   = time.time() - config.start_time

# ————————————————————————————————————————————————————————————————
# --- FASE 2:  estadisticos de los grafos ---
results = analyze_graphs(graphs_info,
                         output_filename=config.grafos_directos2,
                         record_every=100)
t_analysis   = time.time() - config.start_time

# ————————————————————————————————————————————————————————————————
# --- FASE 3: recíprocos --------
convert_and_save_line_graphs(config.grafos_directos2,
                             config.grafos_reciprocos3,
                             record_every=100)
t_recip      = time.time() - config.start_time

# ————————————————————————————————————————————————————————————————
# --- FASE 4: Extraer MST --------------------------
compute_and_save_mst_graphs(config.grafos_reciprocos3,
                            config.grafos_mst,
                            record_every=50)
t_mst        = time.time() - config.start_time


# ————————————————————————————————————————————————————————————————
# ————————————————————————————————————————————————————————————————
# ————————————————————————————————————————————————————————————————
# --- FASE 5: Extraer MST - Optuna hyperparameter search
t_opt_start    = time.time() - config.start_time

def objective(trial: optuna.Trial) -> float:
    h_dim      = trial.suggest_categorical("h_dim",      [32, 64, 128])
    z_dim      = trial.suggest_categorical("z_dim",      [16, 32, 64])
    n_layers   = trial.suggest_int        ("n_layers",   2, 4)
    dropout    = trial.suggest_float      ("dropout",    0.1, 0.5)
    act_fn     = trial.suggest_categorical("act_fn",     ["relu", "tanh", "leakyrelu"])
    lr         = trial.suggest_float      ("lr",         1e-4, 1e-2, log=True)
    beta_KL    = trial.suggest_float      ("beta_KL",    1e-3, 1.0, log=True)
    gamma_CE   = trial.suggest_float      ("gamma_CE",   1e-3, 1.0, log=True)
    lam_rec    = trial.suggest_float      ("lam_rec",    0.0, 1.0)
    lam_lat    = trial.suggest_float      ("lam_lat",    0.0, 1.0 - lam_rec)
    eta_fuse   = trial.suggest_float      ("eta_fuse",   0.0, 1.0)
    k_rule     = trial.suggest_int        ("k_rule",     1, 3)
    tau        = trial.suggest_float      ("tau",        0.0, 1.0)

    train_raw, test_raw, val_raw = partition_graphs(
    pkl_file    = r"\grafos\grafos_mst.pkl",
    train       = 200,
    test        = 2000,
    validacion  = 1400,
    min_normals_test=58,
    min_normals_valid=40)

    rule_stats = compute_descriptors_statistics(train_raw)
    scaler     = fit_feature_scaler(train_raw)

    train_ds = GraphDataset(
        train_raw, scaler=scaler,
        rule_stats=rule_stats,
        k_sigma=k_rule, tau=tau
    )
    val_ds = GraphDataset(
        val_raw, scaler=scaler,
        rule_stats=rule_stats,
        k_sigma=k_rule, tau=tau
    )
    train_loader = DataLoader(
        train_ds, batch_size=16, shuffle=True,
        collate_fn=collate_small_graphs
    )
    val_loader = DataLoader(
        val_ds,   batch_size=16, shuffle=False,
        collate_fn=collate_small_graphs
    )

   
    in_dim    = train_ds[0][1].shape[1]
    model     = VGAE(
        in_dim      = in_dim,
        hidden_dim  = h_dim,
        latent_dim  = z_dim,
        num_layers  = n_layers,
        activation  = act_fn,
        dropout     = dropout,
    )
    optimizer = Adam(model.parameters(), lr=lr)
    scheduler = ReduceLROnPlateau(optimizer, mode="max", factor=0.5, patience=5)
    early_st  = EarlyStop(patience=10, delta=1e-4)

    trainer = Trainer(
        model         = model,
        loaders       = (train_loader, val_loader),
        optimizer     = optimizer,
        scheduler     = scheduler,
        early_stopper = early_st,
        beta_KL       = beta_KL,
        gamma_CE      = gamma_CE,
        lambdas       = (lam_rec, lam_lat),
        eta_fuse      = eta_fuse,
        device        = "cpu",
    )

    best_val_mcc = trainer.fit(epochs=50, trial=trial)
    return best_val_mcc


sampler = optuna.samplers.TPESampler(seed=42)
pruner  = optuna.pruners.MedianPruner(n_warmup_steps=5)
study   = optuna.create_study(direction="maximize",
                              sampler=sampler,
                              pruner=pruner)
study.optimize(objective, n_trials=40)

t_opt_end      = time.time() - config.start_time

# ————————————————————————————————————————————————————————————————
best = study.best_params

train_raw, test_raw, val_raw = partition_graphs(
    pkl_file          = r"\grafos\grafos_mst.pkl",
    train             = 200,
    test              = 1500,
    validacion        = 1500,
    min_normals_test  = 68,
    min_normals_valid = 30,
)

rule_stats = compute_descriptors_statistics(train_raw)
scaler     = fit_feature_scaler(train_raw)

trainval_raw     = train_raw + val_raw
trainval_ds      = GraphDataset(trainval_raw, scaler, rule_stats,
                                k_sigma=best["k_rule"], tau=best["tau"])
test_ds          = GraphDataset(test_raw,    scaler, rule_stats,
                                k_sigma=best["k_rule"], tau=best["tau"])

trainval_loader  = DataLoader(trainval_ds, batch_size=16, shuffle=True,
                              collate_fn=collate_small_graphs)
test_loader      = DataLoader(test_ds,     batch_size=16, shuffle=False,
                              collate_fn=collate_small_graphs)

in_dim    = trainval_ds[0][1].shape[1]
model     = VGAE(
    in_dim      = in_dim,
    hidden_dim  = best["h_dim"],
    latent_dim  = best["z_dim"],
    num_layers  = best["n_layers"],
    activation  = best["act_fn"],
    dropout     = best["dropout"],
)
optimizer = Adam(model.parameters(), lr=best["lr"])
scheduler = ReduceLROnPlateau(optimizer, mode="max", factor=0.5, patience=5)
early_st  = EarlyStop(patience=10, delta=1e-4)

trainer = Trainer(
    model         = model,
    loaders       = (trainval_loader, test_loader),
    optimizer     = optimizer,
    scheduler     = scheduler,
    early_stopper = early_st,
    beta_KL       = best["beta_KL"],
    gamma_CE      = best["gamma_CE"],
    lambdas       = (best["lam_rec"], best["lam_lat"]),
    eta_fuse      = best["eta_fuse"],
    device        = "cpu",
)


start_final = time.time()
best_val_mcc = trainer.fit(epochs=20, trial=None)
t_final_train = time.time() - start_final

scores, latents, p_hats, s_syms, y_true = trainer.evaluate(test_loader)

s_neural = [
    best["lam_rec"] * rec
  + best["lam_lat"] * lat
  + (1 - best["lam_rec"] - best["lam_lat"]) * p
  for rec, lat, p in zip(scores, latents, p_hats)
]
s_final  = [
    best["eta_fuse"] * sn + (1 - best["eta_fuse"]) * ss
    for sn, ss in zip(s_neural, s_syms)
]

y_pred = [1 if sf >= trainer.best_thr else 0 for sf in s_final]

print(">>> TEST MCC:", matthews_corrcoef(y_true, y_pred))
print("\nClassification Report:\n",
      classification_report(y_true, y_pred,
                            labels=[0,1],
                            target_names=["Normal","Anomaly"],
                            digits=4))
print("\nConfusion Matrix:\n",
      confusion_matrix(y_true, y_pred, labels=[0,1]))

t_final = time.time() - config.start_time
print(f"\n(Fase 7 completada en {t_final:.1f}s desde el inicio)")



times = config.memory_times
mems  = config.memory_values

fig, ax = plt.subplots(figsize=(12,5))
ax.plot(times, mems, '-o', label='Memory (GB)')

ax.axvspan(0.0,           t_fs_complete, color='C0', alpha=0.3, label='0. Feature sel.')
ax.axvspan(t_fs_complete, t_directos,    color='C1', alpha=0.3, label='1. Direct graphs')
ax.axvspan(t_directos,    t_analysis,    color='C2', alpha=0.3, label='2. Analysis graphs')
ax.axvspan(t_analysis,    t_recip,       color='C3', alpha=0.3, label='3. Reciprocal graphs')
ax.axvspan(t_recip,       t_mst,         color='C4', alpha=0.3, label='4. MST extraction')
ax.axvspan(t_opt_start,   t_opt_end,     color='C5', alpha=0.3, label='5. Optuna search')
ax.axvspan(t_opt_end,     t_final,       color='C6', alpha=0.3, label='6. Final test')

ax.set_xlabel("Time (s)")
ax.set_ylabel("Memory (GB)")
ax.set_title("Memory vs time in the pipeline")
ax.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()
# Out:
# [I 2025-04-23 23:54:27,890] A new study created in memory with name: no-name-7d7d3b97-0d51-48dc-97c8-d8c96ba3bbb4
# 2025-04-23 23:54:27,893 - INFO - Loading graphs from \grafos\grafos_mst.pkl
# 2025-04-23 23:54:37,965 - INFO - Total loaded: 4304
# 2025-04-23 23:54:37,968 - INFO - Training set: 200 normals
# 2025-04-23 23:54:37,971 - INFO - Test set: 2000 graphs (58 normals)
# 2025-04-23 23:54:37,972 - INFO - Validation set: 1400 graphs (40 normals)
# Graphs loaded from \grafos\grafos_mst.pkl
# 2025-04-23 23:54:41,331 - INFO - Partitioning done: train=200, test=2000, valid=1400
# 2025-04-23 23:54:41,352 - INFO - Descriptor 'num_nodes': mean = 4.0200, std = 1.9182
# 2025-04-23 23:54:41,353 - INFO - Descriptor 'num_edges': mean = 2.1650, std = 1.2197
# 2025-04-23 23:54:41,353 - INFO - Descriptor 'density': mean = 0.5315, std = 0.3388
# 2025-04-23 23:54:41,353 - INFO - Descriptor 'average_degree': mean = 1.0542, std = 0.1095
# 2025-04-23 23:54:41,354 - INFO - Descriptor 'average_clustering': mean = 0.0015, std = 0.0212
# 2025-04-23 23:54:41,354 - INFO - Descriptor 'diameter': mean = nan, std = nan
# 2025-04-23 23:54:41,355 - INFO - Descriptor 'average_shortest_path_length': mean = nan, std = nan
# 2025-04-23 23:54:41,355 - INFO - Descriptor 'spectral_gap': mean = 1.7748, std = 0.4271
# 2025-04-23 23:54:41,355 - INFO - Descriptor 'data_mean_Src_Port': mean = 15094.9909, std = 12951.6082
# 2025-04-23 23:54:41,356 - INFO - Descriptor 'data_mean_Dst_Port': mean = 42682.3978, std = 12974.1427
# 2025-04-23 23:54:41,356 - INFO - Descriptor 'data_mean_Protocol': mean = 6.0250, std = 0.1143
# 2025-04-23 23:54:41,356 - INFO - Descriptor 'data_mean_Flow_Duration': mean = 335.3306, std = 38.5233
# 2025-04-23 23:54:41,357 - INFO - Descriptor 'data_mean_Tot_Fwd_Pkts': mean = 1.2083, std = 0.2820
# 2025-04-23 23:54:41,357 - INFO - Descriptor 'data_mean_TotLen_Fwd_Pkts': mean = 1154.6975, std = 528.8978
# 2025-04-23 23:54:41,357 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Min': mean = 372.8626, std = 258.1980
# 2025-04-23 23:54:41,357 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Std': mean = 188.7862, std = 105.5948
# 2025-04-23 23:54:41,358 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Max': mean = 874.7218, std = 185.6537
# 2025-04-23 23:54:41,359 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Min': mean = 773.4467, std = 220.0364
# 2025-04-23 23:54:41,359 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Std': mean = 62.8895, std = 82.3690
# 2025-04-23 23:54:41,359 - INFO - Descriptor 'data_mean_Flow_Byts/s': mean = 7834078.4959, std = 2241333.1052
# 2025-04-23 23:54:41,360 - INFO - Descriptor 'data_mean_Flow_Pkts/s': mean = 10749.9895, std = 1836.1021
# 2025-04-23 23:54:41,360 - INFO - Descriptor 'data_mean_Flow_IAT_Mean': mean = 209.1243, std = 28.4076
# 2025-04-23 23:54:41,360 - INFO - Descriptor 'data_mean_Flow_IAT_Std': mean = 42.7564, std = 11.5406
# 2025-04-23 23:54:41,361 - INFO - Descriptor 'data_mean_Flow_IAT_Max': mean = 247.6442, std = 29.5370
# 2025-04-23 23:54:41,361 - INFO - Descriptor 'data_mean_Flow_IAT_Min': mean = 178.5237, std = 29.2998
# 2025-04-23 23:54:41,361 - INFO - Descriptor 'data_mean_Fwd_IAT_Tot': mean = 83.6093, std = 25.1289
# 2025-04-23 23:54:41,362 - INFO - Descriptor 'data_mean_Fwd_IAT_Mean': mean = 53.7956, std = 17.0264
# 2025-04-23 23:54:41,362 - INFO - Descriptor 'data_mean_Fwd_IAT_Std': mean = 10.8715, std = 4.9790
# 2025-04-23 23:54:41,362 - INFO - Descriptor 'data_mean_Fwd_IAT_Max': mean = 62.3155, std = 18.4090
# 2025-04-23 23:54:41,363 - INFO - Descriptor 'data_mean_Fwd_IAT_Min': mean = 46.0286, std = 16.2943
# 2025-04-23 23:54:41,363 - INFO - Descriptor 'data_mean_Bwd_IAT_Tot': mean = 139.9642, std = 51.7750
# 2025-04-23 23:54:41,363 - INFO - Descriptor 'data_mean_Bwd_IAT_Mean': mean = 95.8665, std = 28.2007
# 2025-04-23 23:54:41,364 - INFO - Descriptor 'data_mean_Bwd_IAT_Std': mean = 18.5087, std = 11.1206
# 2025-04-23 23:54:41,364 - INFO - Descriptor 'data_mean_Bwd_IAT_Max': mean = 112.7778, std = 34.4228
# 2025-04-23 23:54:41,364 - INFO - Descriptor 'data_mean_Bwd_IAT_Min': mean = 83.3764, std = 24.7365
# 2025-04-23 23:54:41,365 - INFO - Descriptor 'data_mean_Fwd_PSH_Flags': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,365 - INFO - Descriptor 'data_mean_Bwd_PSH_Flags': mean = 0.0586, std = 0.0837
# 2025-04-23 23:54:41,365 - INFO - Descriptor 'data_mean_Fwd_URG_Flags': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,366 - INFO - Descriptor 'data_mean_Fwd_Header_Len': mean = 38.3954, std = 9.1837
# 2025-04-23 23:54:41,366 - INFO - Descriptor 'data_mean_Bwd_Header_Len': mean = 54.4435, std = 12.1511
# 2025-04-23 23:54:41,366 - INFO - Descriptor 'data_mean_Fwd_Pkts/s': mean = 4181.7670, std = 1390.1280
# 2025-04-23 23:54:41,367 - INFO - Descriptor 'data_mean_Bwd_Pkts/s': mean = 6568.2225, std = 1306.2369
# 2025-04-23 23:54:41,367 - INFO - Descriptor 'data_mean_Pkt_Len_Min': mean = 413.2807, std = 243.0801
# 2025-04-23 23:54:41,367 - INFO - Descriptor 'data_mean_Pkt_Len_Max': mean = 897.7900, std = 186.5234
# 2025-04-23 23:54:41,368 - INFO - Descriptor 'data_mean_Pkt_Len_Mean': mean = 763.9637, std = 185.4068
# 2025-04-23 23:54:41,368 - INFO - Descriptor 'data_mean_Pkt_Len_Std': mean = 239.4902, std = 78.0561
# 2025-04-23 23:54:41,368 - INFO - Descriptor 'data_mean_Pkt_Len_Var': mean = 157985.4707, std = 57188.4969
# 2025-04-23 23:54:41,369 - INFO - Descriptor 'data_mean_FIN_Flag_Cnt': mean = 0.0004, std = 0.0020
# 2025-04-23 23:54:41,369 - INFO - Descriptor 'data_mean_SYN_Flag_Cnt': mean = 0.0005, std = 0.0024
# 2025-04-23 23:54:41,369 - INFO - Descriptor 'data_mean_RST_Flag_Cnt': mean = 0.0002, std = 0.0016
# 2025-04-23 23:54:41,369 - INFO - Descriptor 'data_mean_ACK_Flag_Cnt': mean = 0.9962, std = 0.0108
# 2025-04-23 23:54:41,370 - INFO - Descriptor 'data_mean_URG_Flag_Cnt': mean = 0.0001, std = 0.0007
# 2025-04-23 23:54:41,370 - INFO - Descriptor 'data_mean_CWE_Flag_Count': mean = 0.0002, std = 0.0014
# 2025-04-23 23:54:41,370 - INFO - Descriptor 'data_mean_ECE_Flag_Cnt': mean = 0.0004, std = 0.0023
# 2025-04-23 23:54:41,371 - INFO - Descriptor 'data_mean_Down/Up_Ratio': mean = 0.2753, std = 0.1316
# 2025-04-23 23:54:41,371 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Avg': mean = 558.6650, std = 262.5945
# 2025-04-23 23:54:41,371 - INFO - Descriptor 'data_mean_Fwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,372 - INFO - Descriptor 'data_mean_Fwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,372 - INFO - Descriptor 'data_mean_Fwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,372 - INFO - Descriptor 'data_mean_Bwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,373 - INFO - Descriptor 'data_mean_Bwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,373 - INFO - Descriptor 'data_mean_Bwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,373 - INFO - Descriptor 'data_mean_Subflow_Bwd_Pkts': mean = 1.7148, std = 0.3747
# 2025-04-23 23:54:41,374 - INFO - Descriptor 'data_mean_Subflow_Bwd_Byts': mean = 1068.9269, std = 486.7214
# 2025-04-23 23:54:41,374 - INFO - Descriptor 'data_mean_Init_Fwd_Win_Byts': mean = -1.0000, std = 0.0000
# 2025-04-23 23:54:41,374 - INFO - Descriptor 'data_mean_Init_Bwd_Win_Byts': mean = 13315.3222, std = 4221.6063
# 2025-04-23 23:54:41,374 - INFO - Descriptor 'data_mean_Fwd_Act_Data_Pkts': mean = 1.1089, std = 0.4442
# 2025-04-23 23:54:41,375 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Min': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,375 - INFO - Descriptor 'data_mean_Active_Mean': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,375 - INFO - Descriptor 'data_mean_Active_Std': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,376 - INFO - Descriptor 'data_mean_Active_Max': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,376 - INFO - Descriptor 'data_mean_Active_Min': mean = 0.0000, std = 0.0000
# 2025-04-23 23:54:41,376 - INFO - Descriptor 'data_mean_Idle_Mean': mean = 208.2187, std = 30.7501
# 2025-04-23 23:54:41,377 - INFO - Descriptor 'data_mean_Idle_Std': mean = 42.7281, std = 11.5467
# 2025-04-23 23:54:41,377 - INFO - Descriptor 'data_mean_Idle_Min': mean = 177.6359, std = 31.2045
# 2025-04-23 23:54:53,857 - INFO - Epoch 001 | loss=9.862 val_MCC=0.8021 thr=0.8178
# 2025-04-23 23:55:01,494 - INFO - Epoch 002 | loss=7.156 val_MCC=0.8021 thr=0.8192
# 2025-04-23 23:55:10,074 - INFO - Epoch 003 | loss=7.143 val_MCC=0.8177 thr=0.8098
# 2025-04-23 23:55:18,962 - INFO - Epoch 004 | loss=6.405 val_MCC=0.8177 thr=0.8125
# 2025-04-23 23:55:26,401 - INFO - Epoch 005 | loss=7.442 val_MCC=0.8024 thr=0.8149
# 2025-04-23 23:55:34,993 - INFO - Epoch 006 | loss=7.103 val_MCC=0.8330 thr=0.8143
# 2025-04-23 23:55:43,961 - INFO - Epoch 007 | loss=6.511 val_MCC=0.8021 thr=0.8078
# 2025-04-23 23:55:50,582 - INFO - Epoch 008 | loss=6.331 val_MCC=0.8021 thr=0.8060
# 2025-04-23 23:55:58,484 - INFO - Epoch 009 | loss=7.183 val_MCC=0.8021 thr=0.8070
# 2025-04-23 23:56:06,455 - INFO - Epoch 010 | loss=6.661 val_MCC=0.8036 thr=0.8100
# 2025-04-23 23:56:14,431 - INFO - Epoch 011 | loss=6.767 val_MCC=0.8177 thr=0.8092
# 2025-04-23 23:56:21,184 - INFO - Epoch 012 | loss=6.782 val_MCC=0.8021 thr=0.8077
# 2025-04-23 23:56:27,495 - INFO - Epoch 013 | loss=6.480 val_MCC=0.8021 thr=0.8067
# 2025-04-23 23:56:36,061 - INFO - Epoch 014 | loss=6.293 val_MCC=0.8024 thr=0.8077
# 2025-04-23 23:56:43,562 - INFO - Epoch 015 | loss=6.524 val_MCC=0.8021 thr=0.8084
# 2025-04-23 23:56:52,050 - INFO - Training completed in 127.5s best_MCC=0.8330
# [I 2025-04-23 23:56:52,357] Trial 0 finished with value: 0.8329931278350429 and parameters: {'h_dim': 64, 'z_dim': 16, 'n_layers': 2, 'dropout': 0.4464704583099741, 'act_fn': 'tanh', 'lr': 0.008706020878304856, 'beta_KL': 0.31428808908401085, 'gamma_CE': 0.004335281794951566, 'lam_rec': 0.18182496720710062, 'lam_lat': 0.15005699086369886, 'eta_fuse': 0.3042422429595377, 'k_rule': 2, 'tau': 0.43194501864211576}. Best is trial 0 with value: 0.8329931278350429.
# 2025-04-23 23:56:52,414 - INFO - Loading graphs from \grafos\grafos_mst.pkl
# 2025-04-23 23:57:02,336 - INFO - Total loaded: 4304
# 2025-04-23 23:57:02,339 - INFO - Training set: 200 normals
# 2025-04-23 23:57:02,343 - INFO - Test set: 2000 graphs (58 normals)
# 2025-04-23 23:57:02,344 - INFO - Validation set: 1400 graphs (40 normals)
# Graphs loaded from \grafos\grafos_mst.pkl
# 2025-04-23 23:57:05,922 - INFO - Partitioning done: train=200, test=2000, valid=1400
# 2025-04-23 23:57:05,943 - INFO - Descriptor 'num_nodes': mean = 3.9550, std = 1.9552
# 2025-04-23 23:57:05,944 - INFO - Descriptor 'num_edges': mean = 2.1100, std = 1.2074
# 2025-04-23 23:57:05,944 - INFO - Descriptor 'density': mean = 0.5554, std = 0.3507
# 2025-04-23 23:57:05,944 - INFO - Descriptor 'average_degree': mean = 1.0464, std = 0.1043
# 2025-04-23 23:57:05,945 - INFO - Descriptor 'average_clustering': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,945 - INFO - Descriptor 'diameter': mean = nan, std = nan
# 2025-04-23 23:57:05,945 - INFO - Descriptor 'average_shortest_path_length': mean = nan, std = nan
# 2025-04-23 23:57:05,946 - INFO - Descriptor 'spectral_gap': mean = 1.8098, std = 0.4024
# 2025-04-23 23:57:05,946 - INFO - Descriptor 'data_mean_Src_Port': mean = 15131.5671, std = 12965.3056
# 2025-04-23 23:57:05,947 - INFO - Descriptor 'data_mean_Dst_Port': mean = 42644.8676, std = 12989.9480
# 2025-04-23 23:57:05,947 - INFO - Descriptor 'data_mean_Protocol': mean = 6.0313, std = 0.1408
# 2025-04-23 23:57:05,947 - INFO - Descriptor 'data_mean_Flow_Duration': mean = 334.5945, std = 39.7351
# 2025-04-23 23:57:05,947 - INFO - Descriptor 'data_mean_Tot_Fwd_Pkts': mean = 1.2009, std = 0.3019
# 2025-04-23 23:57:05,948 - INFO - Descriptor 'data_mean_TotLen_Fwd_Pkts': mean = 1126.3186, std = 550.2718
# 2025-04-23 23:57:05,948 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Min': mean = 355.5978, std = 265.9713
# 2025-04-23 23:57:05,948 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Std': mean = 195.8354, std = 115.0324
# 2025-04-23 23:57:05,949 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Max': mean = 874.2686, std = 195.0871
# 2025-04-23 23:57:05,949 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Min': mean = 768.0952, std = 230.6656
# 2025-04-23 23:57:05,949 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Std': mean = 65.9778, std = 87.8760
# 2025-04-23 23:57:05,950 - INFO - Descriptor 'data_mean_Flow_Byts/s': mean = 7742138.5503, std = 2330369.5335
# 2025-04-23 23:57:05,950 - INFO - Descriptor 'data_mean_Flow_Pkts/s': mean = 10753.1022, std = 1840.9841
# 2025-04-23 23:57:05,950 - INFO - Descriptor 'data_mean_Flow_IAT_Mean': mean = 209.2495, std = 29.1526
# 2025-04-23 23:57:05,951 - INFO - Descriptor 'data_mean_Flow_IAT_Std': mean = 43.0913, std = 11.9672
# 2025-04-23 23:57:05,951 - INFO - Descriptor 'data_mean_Flow_IAT_Max': mean = 247.9505, std = 30.0786
# 2025-04-23 23:57:05,951 - INFO - Descriptor 'data_mean_Flow_IAT_Min': mean = 178.4464, std = 30.3981
# 2025-04-23 23:57:05,952 - INFO - Descriptor 'data_mean_Fwd_IAT_Tot': mean = 82.9725, std = 26.7357
# 2025-04-23 23:57:05,952 - INFO - Descriptor 'data_mean_Fwd_IAT_Mean': mean = 53.4427, std = 16.9381
# 2025-04-23 23:57:05,952 - INFO - Descriptor 'data_mean_Fwd_IAT_Std': mean = 10.7492, std = 5.5434
# 2025-04-23 23:57:05,953 - INFO - Descriptor 'data_mean_Fwd_IAT_Max': mean = 61.8846, std = 18.3777
# 2025-04-23 23:57:05,953 - INFO - Descriptor 'data_mean_Fwd_IAT_Min': mean = 45.7715, std = 16.4288
# 2025-04-23 23:57:05,954 - INFO - Descriptor 'data_mean_Bwd_IAT_Tot': mean = 140.6576, std = 51.1412
# 2025-04-23 23:57:05,954 - INFO - Descriptor 'data_mean_Bwd_IAT_Mean': mean = 96.0394, std = 28.2253
# 2025-04-23 23:57:05,954 - INFO - Descriptor 'data_mean_Bwd_IAT_Std': mean = 19.0164, std = 11.2914
# 2025-04-23 23:57:05,954 - INFO - Descriptor 'data_mean_Bwd_IAT_Max': mean = 113.3069, std = 34.6892
# 2025-04-23 23:57:05,955 - INFO - Descriptor 'data_mean_Bwd_IAT_Min': mean = 83.2009, std = 24.5822
# 2025-04-23 23:57:05,955 - INFO - Descriptor 'data_mean_Fwd_PSH_Flags': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,955 - INFO - Descriptor 'data_mean_Bwd_PSH_Flags': mean = 0.0580, std = 0.0837
# 2025-04-23 23:57:05,956 - INFO - Descriptor 'data_mean_Fwd_URG_Flags': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,956 - INFO - Descriptor 'data_mean_Fwd_Header_Len': mean = 38.0849, std = 9.7820
# 2025-04-23 23:57:05,956 - INFO - Descriptor 'data_mean_Bwd_Header_Len': mean = 54.4442, std = 11.9892
# 2025-04-23 23:57:05,957 - INFO - Descriptor 'data_mean_Fwd_Pkts/s': mean = 4186.2871, std = 1420.2418
# 2025-04-23 23:57:05,957 - INFO - Descriptor 'data_mean_Bwd_Pkts/s': mean = 6566.8151, std = 1306.8925
# 2025-04-23 23:57:05,957 - INFO - Descriptor 'data_mean_Pkt_Len_Min': mean = 393.5146, std = 260.4534
# 2025-04-23 23:57:05,958 - INFO - Descriptor 'data_mean_Pkt_Len_Max': mean = 896.5231, std = 195.0718
# 2025-04-23 23:57:05,958 - INFO - Descriptor 'data_mean_Pkt_Len_Mean': mean = 757.1895, std = 196.1962
# 2025-04-23 23:57:05,958 - INFO - Descriptor 'data_mean_Pkt_Len_Std': mean = 249.5970, std = 82.0266
# 2025-04-23 23:57:05,958 - INFO - Descriptor 'data_mean_Pkt_Len_Var': mean = 165677.2844, std = 60712.4360
# 2025-04-23 23:57:05,959 - INFO - Descriptor 'data_mean_FIN_Flag_Cnt': mean = 0.0006, std = 0.0038
# 2025-04-23 23:57:05,961 - INFO - Descriptor 'data_mean_SYN_Flag_Cnt': mean = 0.0006, std = 0.0039
# 2025-04-23 23:57:05,961 - INFO - Descriptor 'data_mean_RST_Flag_Cnt': mean = 0.0003, std = 0.0022
# 2025-04-23 23:57:05,961 - INFO - Descriptor 'data_mean_ACK_Flag_Cnt': mean = 0.9952, std = 0.0131
# 2025-04-23 23:57:05,962 - INFO - Descriptor 'data_mean_URG_Flag_Cnt': mean = 0.0001, std = 0.0007
# 2025-04-23 23:57:05,962 - INFO - Descriptor 'data_mean_CWE_Flag_Count': mean = 0.0003, std = 0.0020
# 2025-04-23 23:57:05,962 - INFO - Descriptor 'data_mean_ECE_Flag_Cnt': mean = 0.0006, std = 0.0038
# 2025-04-23 23:57:05,963 - INFO - Descriptor 'data_mean_Down/Up_Ratio': mean = 0.2779, std = 0.1376
# 2025-04-23 23:57:05,963 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Avg': mean = 545.6619, std = 265.3983
# 2025-04-23 23:57:05,963 - INFO - Descriptor 'data_mean_Fwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,964 - INFO - Descriptor 'data_mean_Fwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,964 - INFO - Descriptor 'data_mean_Fwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,964 - INFO - Descriptor 'data_mean_Bwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,965 - INFO - Descriptor 'data_mean_Bwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,965 - INFO - Descriptor 'data_mean_Bwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,965 - INFO - Descriptor 'data_mean_Subflow_Bwd_Pkts': mean = 1.7156, std = 0.3708
# 2025-04-23 23:57:05,966 - INFO - Descriptor 'data_mean_Subflow_Bwd_Byts': mean = 1063.8218, std = 488.2025
# 2025-04-23 23:57:05,966 - INFO - Descriptor 'data_mean_Init_Fwd_Win_Byts': mean = -1.0000, std = 0.0000
# 2025-04-23 23:57:05,966 - INFO - Descriptor 'data_mean_Init_Bwd_Win_Byts': mean = 13268.7651, std = 4349.5710
# 2025-04-23 23:57:05,967 - INFO - Descriptor 'data_mean_Fwd_Act_Data_Pkts': mean = 1.1004, std = 0.4528
# 2025-04-23 23:57:05,967 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Min': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,967 - INFO - Descriptor 'data_mean_Active_Mean': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,968 - INFO - Descriptor 'data_mean_Active_Std': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,968 - INFO - Descriptor 'data_mean_Active_Max': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,968 - INFO - Descriptor 'data_mean_Active_Min': mean = 0.0000, std = 0.0000
# 2025-04-23 23:57:05,969 - INFO - Descriptor 'data_mean_Idle_Mean': mean = 208.1616, std = 31.4833
# 2025-04-23 23:57:05,969 - INFO - Descriptor 'data_mean_Idle_Std': mean = 43.0617, std = 11.9830
# 2025-04-23 23:57:05,970 - INFO - Descriptor 'data_mean_Idle_Min': mean = 177.3760, std = 32.2249
# 2025-04-23 23:57:16,698 - INFO - Epoch 001 | loss=34.026 val_MCC=0.4703 thr=0.2122
# 2025-04-23 23:57:25,840 - INFO - Epoch 002 | loss=28.968 val_MCC=0.3491 thr=0.2103
# 2025-04-23 23:57:36,355 - INFO - Epoch 003 | loss=33.570 val_MCC=0.4133 thr=0.2103
# 2025-04-23 23:57:45,555 - INFO - Epoch 004 | loss=31.350 val_MCC=0.4133 thr=0.2155
# 2025-04-23 23:57:55,402 - INFO - Epoch 005 | loss=29.548 val_MCC=0.3825 thr=0.2139
# 2025-04-23 23:58:03,657 - INFO - Epoch 006 | loss=22.631 val_MCC=0.3169 thr=0.2172
# 2025-04-23 23:58:12,395 - INFO - Epoch 007 | loss=20.225 val_MCC=0.2702 thr=0.2096
# 2025-04-23 23:58:20,610 - INFO - Epoch 008 | loss=20.589 val_MCC=0.3121 thr=0.2090
# 2025-04-23 23:58:28,565 - INFO - Epoch 009 | loss=18.397 val_MCC=0.2702 thr=0.2130
# 2025-04-23 23:58:38,279 - INFO - Epoch 010 | loss=19.541 val_MCC=0.2205 thr=0.2077
# 2025-04-23 23:58:46,670 - INFO - Training completed in 97.4s best_MCC=0.4703
# [I 2025-04-23 23:58:46,988] Trial 1 finished with value: 0.4703409307329776 and parameters: {'h_dim': 64, 'z_dim': 64, 'n_layers': 4, 'dropout': 0.1798695128633439, 'act_fn': 'tanh', 'lr': 0.0016409286730647919, 'beta_KL': 0.0032476735706274485, 'gamma_CE': 0.001567309546723541, 'lam_rec': 0.9488855372533332, 'lam_lat': 0.04935776258157765, 'eta_fuse': 0.8083973481164611, 'k_rule': 1, 'tau': 0.09767211400638387}. Best is trial 0 with value: 0.8329931278350429.
# 2025-04-23 23:58:47,039 - INFO - Loading graphs from \grafos\grafos_mst.pkl
# 2025-04-23 23:58:56,700 - INFO - Total loaded: 4304
# 2025-04-23 23:58:56,704 - INFO - Training set: 200 normals
# 2025-04-23 23:58:56,708 - INFO - Test set: 2000 graphs (58 normals)
# 2025-04-23 23:58:56,710 - INFO - Validation set: 1400 graphs (40 normals)
# Graphs loaded from \grafos\grafos_mst.pkl
# 2025-04-23 23:59:00,109 - INFO - Partitioning done: train=200, test=2000, valid=1400
# 2025-04-23 23:59:00,129 - INFO - Descriptor 'num_nodes': mean = 4.0600, std = 1.8805
# 2025-04-23 23:59:00,130 - INFO - Descriptor 'num_edges': mean = 2.1900, std = 1.1636
# 2025-04-23 23:59:00,130 - INFO - Descriptor 'density': mean = 0.5257, std = 0.3376
# 2025-04-23 23:59:00,131 - INFO - Descriptor 'average_degree': mean = 1.0589, std = 0.1141
# 2025-04-23 23:59:00,131 - INFO - Descriptor 'average_clustering': mean = 0.0015, std = 0.0212
# 2025-04-23 23:59:00,131 - INFO - Descriptor 'diameter': mean = nan, std = nan
# 2025-04-23 23:59:00,132 - INFO - Descriptor 'average_shortest_path_length': mean = nan, std = nan
# 2025-04-23 23:59:00,132 - INFO - Descriptor 'spectral_gap': mean = 1.7628, std = 0.4380
# 2025-04-23 23:59:00,132 - INFO - Descriptor 'data_mean_Src_Port': mean = 15807.2953, std = 12990.3031
# 2025-04-23 23:59:00,133 - INFO - Descriptor 'data_mean_Dst_Port': mean = 42116.5938, std = 13127.4543
# 2025-04-23 23:59:00,134 - INFO - Descriptor 'data_mean_Protocol': mean = 6.0355, std = 0.1524
# 2025-04-23 23:59:00,134 - INFO - Descriptor 'data_mean_Flow_Duration': mean = 338.9654, std = 26.4120
# 2025-04-23 23:59:00,135 - INFO - Descriptor 'data_mean_Tot_Fwd_Pkts': mean = 1.2218, std = 0.2967
# 2025-04-23 23:59:00,135 - INFO - Descriptor 'data_mean_TotLen_Fwd_Pkts': mean = 1162.3871, std = 548.3301
# 2025-04-23 23:59:00,135 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Min': mean = 371.2134, std = 257.9347
# 2025-04-23 23:59:00,137 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Std': mean = 189.6988, std = 107.9797
# 2025-04-23 23:59:00,137 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Max': mean = 890.5462, std = 170.2242
# 2025-04-23 23:59:00,137 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Min': mean = 782.9131, std = 213.1147
# 2025-04-23 23:59:00,138 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Std': mean = 66.2636, std = 83.9145
# 2025-04-23 23:59:00,138 - INFO - Descriptor 'data_mean_Flow_Byts/s': mean = 7928850.2535, std = 2152823.4301
# 2025-04-23 23:59:00,138 - INFO - Descriptor 'data_mean_Flow_Pkts/s': mean = 10568.2777, std = 1203.2848
# 2025-04-23 23:59:00,139 - INFO - Descriptor 'data_mean_Flow_IAT_Mean': mean = 211.1335, std = 27.0726
# 2025-04-23 23:59:00,139 - INFO - Descriptor 'data_mean_Flow_IAT_Std': mean = 43.0542, std = 9.0796
# 2025-04-23 23:59:00,139 - INFO - Descriptor 'data_mean_Flow_IAT_Max': mean = 250.0379, std = 25.6440
# 2025-04-23 23:59:00,140 - INFO - Descriptor 'data_mean_Flow_IAT_Min': mean = 180.2951, std = 28.7874
# 2025-04-23 23:59:00,140 - INFO - Descriptor 'data_mean_Fwd_IAT_Tot': mean = 85.7897, std = 25.8364
# 2025-04-23 23:59:00,141 - INFO - Descriptor 'data_mean_Fwd_IAT_Mean': mean = 54.8870, std = 16.6316
# 2025-04-23 23:59:00,141 - INFO - Descriptor 'data_mean_Fwd_IAT_Std': mean = 11.1272, std = 5.2262
# 2025-04-23 23:59:00,141 - INFO - Descriptor 'data_mean_Fwd_IAT_Max': mean = 63.6185, std = 17.9111
# 2025-04-23 23:59:00,142 - INFO - Descriptor 'data_mean_Fwd_IAT_Min': mean = 46.9401, std = 16.1121
# 2025-04-23 23:59:00,142 - INFO - Descriptor 'data_mean_Bwd_IAT_Tot': mean = 139.7212, std = 43.0515
# 2025-04-23 23:59:00,142 - INFO - Descriptor 'data_mean_Bwd_IAT_Mean': mean = 95.8015, std = 26.4584
# 2025-04-23 23:59:00,143 - INFO - Descriptor 'data_mean_Bwd_IAT_Std': mean = 18.1356, std = 7.7213
# 2025-04-23 23:59:00,143 - INFO - Descriptor 'data_mean_Bwd_IAT_Max': mean = 112.4447, std = 31.2598
# 2025-04-23 23:59:00,143 - INFO - Descriptor 'data_mean_Bwd_IAT_Min': mean = 83.5190, std = 23.3818
# 2025-04-23 23:59:00,144 - INFO - Descriptor 'data_mean_Fwd_PSH_Flags': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,144 - INFO - Descriptor 'data_mean_Bwd_PSH_Flags': mean = 0.0513, std = 0.0409
# 2025-04-23 23:59:00,144 - INFO - Descriptor 'data_mean_Fwd_URG_Flags': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,145 - INFO - Descriptor 'data_mean_Fwd_Header_Len': mean = 38.7647, std = 9.5443
# 2025-04-23 23:59:00,145 - INFO - Descriptor 'data_mean_Bwd_Header_Len': mean = 54.3809, std = 9.2431
# 2025-04-23 23:59:00,145 - INFO - Descriptor 'data_mean_Fwd_Pkts/s': mean = 4098.6307, std = 1073.9013
# 2025-04-23 23:59:00,146 - INFO - Descriptor 'data_mean_Bwd_Pkts/s': mean = 6469.6470, std = 1179.1068
# 2025-04-23 23:59:00,146 - INFO - Descriptor 'data_mean_Pkt_Len_Min': mean = 420.2467, std = 245.4893
# 2025-04-23 23:59:00,146 - INFO - Descriptor 'data_mean_Pkt_Len_Max': mean = 912.9924, std = 170.9331
# 2025-04-23 23:59:00,147 - INFO - Descriptor 'data_mean_Pkt_Len_Mean': mean = 777.3602, std = 174.6879
# 2025-04-23 23:59:00,147 - INFO - Descriptor 'data_mean_Pkt_Len_Std': mean = 243.4004, std = 75.6798
# 2025-04-23 23:59:00,147 - INFO - Descriptor 'data_mean_Pkt_Len_Var': mean = 161186.4392, std = 55814.5342
# 2025-04-23 23:59:00,148 - INFO - Descriptor 'data_mean_FIN_Flag_Cnt': mean = 0.0007, std = 0.0039
# 2025-04-23 23:59:00,148 - INFO - Descriptor 'data_mean_SYN_Flag_Cnt': mean = 0.0006, std = 0.0040
# 2025-04-23 23:59:00,148 - INFO - Descriptor 'data_mean_RST_Flag_Cnt': mean = 0.0003, std = 0.0022
# 2025-04-23 23:59:00,149 - INFO - Descriptor 'data_mean_ACK_Flag_Cnt': mean = 0.9951, std = 0.0141
# 2025-04-23 23:59:00,151 - INFO - Descriptor 'data_mean_URG_Flag_Cnt': mean = 0.0001, std = 0.0007
# 2025-04-23 23:59:00,151 - INFO - Descriptor 'data_mean_CWE_Flag_Count': mean = 0.0002, std = 0.0020
# 2025-04-23 23:59:00,151 - INFO - Descriptor 'data_mean_ECE_Flag_Cnt': mean = 0.0006, std = 0.0039
# 2025-04-23 23:59:00,152 - INFO - Descriptor 'data_mean_Down/Up_Ratio': mean = 0.2706, std = 0.1109
# 2025-04-23 23:59:00,152 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Avg': mean = 557.9880, std = 262.8027
# 2025-04-23 23:59:00,152 - INFO - Descriptor 'data_mean_Fwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,153 - INFO - Descriptor 'data_mean_Fwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,153 - INFO - Descriptor 'data_mean_Fwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,153 - INFO - Descriptor 'data_mean_Bwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,154 - INFO - Descriptor 'data_mean_Bwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,154 - INFO - Descriptor 'data_mean_Bwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,154 - INFO - Descriptor 'data_mean_Subflow_Bwd_Pkts': mean = 1.7128, std = 0.2900
# 2025-04-23 23:59:00,155 - INFO - Descriptor 'data_mean_Subflow_Bwd_Byts': mean = 1111.6108, std = 497.2011
# 2025-04-23 23:59:00,155 - INFO - Descriptor 'data_mean_Init_Fwd_Win_Byts': mean = -1.0000, std = 0.0000
# 2025-04-23 23:59:00,155 - INFO - Descriptor 'data_mean_Init_Bwd_Win_Byts': mean = 13054.5258, std = 3501.8904
# 2025-04-23 23:59:00,156 - INFO - Descriptor 'data_mean_Fwd_Act_Data_Pkts': mean = 1.1178, std = 0.4564
# 2025-04-23 23:59:00,156 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Min': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,156 - INFO - Descriptor 'data_mean_Active_Mean': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,157 - INFO - Descriptor 'data_mean_Active_Std': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,157 - INFO - Descriptor 'data_mean_Active_Max': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,157 - INFO - Descriptor 'data_mean_Active_Min': mean = 0.0000, std = 0.0000
# 2025-04-23 23:59:00,158 - INFO - Descriptor 'data_mean_Idle_Mean': mean = 210.4880, std = 27.0431
# 2025-04-23 23:59:00,158 - INFO - Descriptor 'data_mean_Idle_Std': mean = 43.0222, std = 9.1005
# 2025-04-23 23:59:00,158 - INFO - Descriptor 'data_mean_Idle_Min': mean = 179.6687, std = 28.7468
# 2025-04-23 23:59:11,795 - INFO - Epoch 001 | loss=166.920 val_MCC=0.6655 thr=0.4301
# 2025-04-23 23:59:20,449 - INFO - Epoch 002 | loss=159.071 val_MCC=0.6465 thr=0.4287
# 2025-04-23 23:59:29,975 - INFO - Epoch 003 | loss=153.547 val_MCC=0.6269 thr=0.4273
# 2025-04-23 23:59:39,500 - INFO - Epoch 004 | loss=147.816 val_MCC=0.5645 thr=0.4257
# 2025-04-23 23:59:48,698 - INFO - Epoch 005 | loss=146.764 val_MCC=0.6465 thr=0.4244
# 2025-04-23 23:59:57,170 - INFO - Epoch 006 | loss=135.943 val_MCC=0.6465 thr=0.4230
# 2025-04-24 00:00:05,289 - INFO - Epoch 007 | loss=132.871 val_MCC=0.6269 thr=0.4213
# 2025-04-24 00:00:14,092 - INFO - Epoch 008 | loss=124.677 val_MCC=0.6839 thr=0.4206
# 2025-04-24 00:00:21,595 - INFO - Epoch 009 | loss=122.250 val_MCC=0.6269 thr=0.4202
# 2025-04-24 00:00:30,531 - INFO - Epoch 010 | loss=119.552 val_MCC=0.6269 thr=0.4195
# 2025-04-24 00:00:38,676 - INFO - Epoch 011 | loss=119.954 val_MCC=0.6655 thr=0.4188
# 2025-04-24 00:00:47,309 - INFO - Epoch 012 | loss=114.485 val_MCC=0.6269 thr=0.4183
# 2025-04-24 00:00:55,900 - INFO - Epoch 013 | loss=111.741 val_MCC=0.6068 thr=0.4176
# 2025-04-24 00:01:04,482 - INFO - Epoch 014 | loss=115.326 val_MCC=0.5860 thr=0.4169
# 2025-04-24 00:01:12,751 - INFO - Epoch 015 | loss=103.995 val_MCC=0.6465 thr=0.4168
# 2025-04-24 00:01:21,668 - INFO - Epoch 016 | loss=109.634 val_MCC=0.6269 thr=0.4166
# 2025-04-24 00:01:30,465 - INFO - Epoch 017 | loss=106.708 val_MCC=0.5645 thr=0.4162
# 2025-04-24 00:01:39,557 - INFO - Training completed in 156.2s best_MCC=0.6839
# [I 2025-04-24 00:01:39,852] Trial 2 finished with value: 0.6839422294374141 and parameters: {'h_dim': 32, 'z_dim': 64, 'n_layers': 2, 'dropout': 0.36500891374159283, 'act_fn': 'leakyrelu', 'lr': 0.00023426581058204064, 'beta_KL': 0.8105016126411579, 'gamma_CE': 0.2115429079726121, 'lam_rec': 0.9394989415641891, 'lam_lat': 0.054138001818185004, 'eta_fuse': 0.5978999788110851, 'k_rule': 3, 'tau': 0.0884925020519195}. Best is trial 0 with value: 0.8329931278350429.
# 2025-04-24 00:01:39,903 - INFO - Loading graphs from \grafos\grafos_mst.pkl
# 2025-04-24 00:01:49,411 - INFO - Total loaded: 4304
# 2025-04-24 00:01:49,414 - INFO - Training set: 200 normals
# 2025-04-24 00:01:49,417 - INFO - Test set: 2000 graphs (58 normals)
# 2025-04-24 00:01:49,418 - INFO - Validation set: 1400 graphs (40 normals)
# Graphs loaded from \grafos\grafos_mst.pkl
# 2025-04-24 00:01:52,776 - INFO - Partitioning done: train=200, test=2000, valid=1400
# 2025-04-24 00:01:52,797 - INFO - Descriptor 'num_nodes': mean = 3.9900, std = 1.8761
# 2025-04-24 00:01:52,797 - INFO - Descriptor 'num_edges': mean = 2.1400, std = 1.1792
# 2025-04-24 00:01:52,798 - INFO - Descriptor 'density': mean = 0.5347, std = 0.3402
# 2025-04-24 00:01:52,798 - INFO - Descriptor 'average_degree': mean = 1.0514, std = 0.1085
# 2025-04-24 00:01:52,798 - INFO - Descriptor 'average_clustering': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,799 - INFO - Descriptor 'diameter': mean = nan, std = nan
# 2025-04-24 00:01:52,799 - INFO - Descriptor 'average_shortest_path_length': mean = nan, std = nan
# 2025-04-24 00:01:52,799 - INFO - Descriptor 'spectral_gap': mean = 1.7878, std = 0.4220
# 2025-04-24 00:01:52,800 - INFO - Descriptor 'data_mean_Src_Port': mean = 15135.7716, std = 12594.2964
# 2025-04-24 00:01:52,800 - INFO - Descriptor 'data_mean_Dst_Port': mean = 42764.7604, std = 12674.6216
# 2025-04-24 00:01:52,800 - INFO - Descriptor 'data_mean_Protocol': mean = 6.0265, std = 0.1198
# 2025-04-24 00:01:52,801 - INFO - Descriptor 'data_mean_Flow_Duration': mean = 335.1981, std = 34.7768
# 2025-04-24 00:01:52,801 - INFO - Descriptor 'data_mean_Tot_Fwd_Pkts': mean = 1.2044, std = 0.2663
# 2025-04-24 00:01:52,801 - INFO - Descriptor 'data_mean_TotLen_Fwd_Pkts': mean = 1125.3866, std = 518.4384
# 2025-04-24 00:01:52,802 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Min': mean = 358.9184, std = 249.5706
# 2025-04-24 00:01:52,802 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Std': mean = 194.2591, std = 107.9361
# 2025-04-24 00:01:52,802 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Max': mean = 870.1550, std = 190.4256
# 2025-04-24 00:01:52,803 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Min': mean = 765.2053, std = 220.0715
# 2025-04-24 00:01:52,803 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Std': mean = 65.2328, std = 82.5957
# 2025-04-24 00:01:52,803 - INFO - Descriptor 'data_mean_Flow_Byts/s': mean = 7653416.8782, std = 1989817.3505
# 2025-04-24 00:01:52,804 - INFO - Descriptor 'data_mean_Flow_Pkts/s': mean = 10696.6414, std = 1793.5454
# 2025-04-24 00:01:52,804 - INFO - Descriptor 'data_mean_Flow_IAT_Mean': mean = 210.9756, std = 27.7453
# 2025-04-24 00:01:52,804 - INFO - Descriptor 'data_mean_Flow_IAT_Std': mean = 42.5906, std = 9.7453
# 2025-04-24 00:01:52,804 - INFO - Descriptor 'data_mean_Flow_IAT_Max': mean = 249.2699, std = 28.4820
# 2025-04-24 00:01:52,805 - INFO - Descriptor 'data_mean_Flow_IAT_Min': mean = 180.4748, std = 28.2774
# 2025-04-24 00:01:52,805 - INFO - Descriptor 'data_mean_Fwd_IAT_Tot': mean = 84.0583, std = 25.7071
# 2025-04-24 00:01:52,805 - INFO - Descriptor 'data_mean_Fwd_IAT_Mean': mean = 54.3997, std = 17.2600
# 2025-04-24 00:01:52,806 - INFO - Descriptor 'data_mean_Fwd_IAT_Std': mean = 10.9419, std = 5.0237
# 2025-04-24 00:01:52,806 - INFO - Descriptor 'data_mean_Fwd_IAT_Max': mean = 62.9721, std = 18.4528
# 2025-04-24 00:01:52,806 - INFO - Descriptor 'data_mean_Fwd_IAT_Min': mean = 46.5803, std = 16.8026
# 2025-04-24 00:01:52,807 - INFO - Descriptor 'data_mean_Bwd_IAT_Tot': mean = 138.0165, std = 41.8557
# 2025-04-24 00:01:52,807 - INFO - Descriptor 'data_mean_Bwd_IAT_Mean': mean = 95.7228, std = 26.1373
# 2025-04-24 00:01:52,807 - INFO - Descriptor 'data_mean_Bwd_IAT_Std': mean = 17.9679, std = 7.6414
# 2025-04-24 00:01:52,808 - INFO - Descriptor 'data_mean_Bwd_IAT_Max': mean = 112.1888, std = 30.8696
# 2025-04-24 00:01:52,808 - INFO - Descriptor 'data_mean_Bwd_IAT_Min': mean = 83.6169, std = 23.2938
# 2025-04-24 00:01:52,808 - INFO - Descriptor 'data_mean_Fwd_PSH_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,808 - INFO - Descriptor 'data_mean_Bwd_PSH_Flags': mean = 0.0563, std = 0.0764
# 2025-04-24 00:01:52,809 - INFO - Descriptor 'data_mean_Fwd_URG_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,809 - INFO - Descriptor 'data_mean_Fwd_Header_Len': mean = 38.2937, std = 8.6734
# 2025-04-24 00:01:52,809 - INFO - Descriptor 'data_mean_Bwd_Header_Len': mean = 53.8377, std = 9.3104
# 2025-04-24 00:01:52,810 - INFO - Descriptor 'data_mean_Fwd_Pkts/s': mean = 4154.4216, std = 1288.9947
# 2025-04-24 00:01:52,810 - INFO - Descriptor 'data_mean_Bwd_Pkts/s': mean = 6542.2198, std = 1294.1622
# 2025-04-24 00:01:52,810 - INFO - Descriptor 'data_mean_Pkt_Len_Min': mean = 395.1230, std = 237.8112
# 2025-04-24 00:01:52,811 - INFO - Descriptor 'data_mean_Pkt_Len_Max': mean = 893.9639, std = 190.0971
# 2025-04-24 00:01:52,811 - INFO - Descriptor 'data_mean_Pkt_Len_Mean': mean = 755.8519, std = 184.7966
# 2025-04-24 00:01:52,811 - INFO - Descriptor 'data_mean_Pkt_Len_Std': mean = 247.1824, std = 79.9212
# 2025-04-24 00:01:52,812 - INFO - Descriptor 'data_mean_Pkt_Len_Var': mean = 164556.7873, std = 58983.6267
# 2025-04-24 00:01:52,812 - INFO - Descriptor 'data_mean_FIN_Flag_Cnt': mean = 0.0007, std = 0.0040
# 2025-04-24 00:01:52,812 - INFO - Descriptor 'data_mean_SYN_Flag_Cnt': mean = 0.0008, std = 0.0042
# 2025-04-24 00:01:52,813 - INFO - Descriptor 'data_mean_RST_Flag_Cnt': mean = 0.0003, std = 0.0022
# 2025-04-24 00:01:52,813 - INFO - Descriptor 'data_mean_ACK_Flag_Cnt': mean = 0.9959, std = 0.0112
# 2025-04-24 00:01:52,813 - INFO - Descriptor 'data_mean_URG_Flag_Cnt': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,814 - INFO - Descriptor 'data_mean_CWE_Flag_Count': mean = 0.0003, std = 0.0021
# 2025-04-24 00:01:52,814 - INFO - Descriptor 'data_mean_ECE_Flag_Cnt': mean = 0.0007, std = 0.0041
# 2025-04-24 00:01:52,814 - INFO - Descriptor 'data_mean_Down/Up_Ratio': mean = 0.2821, std = 0.1302
# 2025-04-24 00:01:52,815 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Avg': mean = 548.3295, std = 255.6874
# 2025-04-24 00:01:52,815 - INFO - Descriptor 'data_mean_Fwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,815 - INFO - Descriptor 'data_mean_Fwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,816 - INFO - Descriptor 'data_mean_Fwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,816 - INFO - Descriptor 'data_mean_Bwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,816 - INFO - Descriptor 'data_mean_Bwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,816 - INFO - Descriptor 'data_mean_Bwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,817 - INFO - Descriptor 'data_mean_Subflow_Bwd_Pkts': mean = 1.6963, std = 0.2845
# 2025-04-24 00:01:52,817 - INFO - Descriptor 'data_mean_Subflow_Bwd_Byts': mean = 1061.3499, std = 476.0495
# 2025-04-24 00:01:52,817 - INFO - Descriptor 'data_mean_Init_Fwd_Win_Byts': mean = -1.0000, std = 0.0000
# 2025-04-24 00:01:52,818 - INFO - Descriptor 'data_mean_Init_Bwd_Win_Byts': mean = 13462.5765, std = 4083.2564
# 2025-04-24 00:01:52,818 - INFO - Descriptor 'data_mean_Fwd_Act_Data_Pkts': mean = 1.0962, std = 0.4391
# 2025-04-24 00:01:52,818 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,819 - INFO - Descriptor 'data_mean_Active_Mean': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,819 - INFO - Descriptor 'data_mean_Active_Std': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,819 - INFO - Descriptor 'data_mean_Active_Max': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,820 - INFO - Descriptor 'data_mean_Active_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:01:52,820 - INFO - Descriptor 'data_mean_Idle_Mean': mean = 209.7932, std = 30.1039
# 2025-04-24 00:01:52,820 - INFO - Descriptor 'data_mean_Idle_Std': mean = 42.5603, std = 9.7577
# 2025-04-24 00:01:52,820 - INFO - Descriptor 'data_mean_Idle_Min': mean = 179.3093, std = 30.1757
# 2025-04-24 00:02:07,036 - INFO - Epoch 001 | loss=65.288 val_MCC=0.7020 thr=0.5378
# 2025-04-24 00:02:16,637 - INFO - Epoch 002 | loss=63.191 val_MCC=0.7536 thr=0.5394
# 2025-04-24 00:02:27,212 - INFO - Epoch 003 | loss=57.970 val_MCC=0.6839 thr=0.5360
# 2025-04-24 00:02:37,987 - INFO - Epoch 004 | loss=54.827 val_MCC=0.6655 thr=0.5372
# 2025-04-24 00:02:48,453 - INFO - Epoch 005 | loss=51.577 val_MCC=0.7196 thr=0.5378
# 2025-04-24 00:02:58,513 - INFO - Epoch 006 | loss=50.582 val_MCC=0.7536 thr=0.5318
# 2025-04-24 00:03:09,326 - INFO - Epoch 007 | loss=48.750 val_MCC=0.6655 thr=0.5373
# 2025-04-24 00:03:18,926 - INFO - Epoch 008 | loss=47.888 val_MCC=0.6655 thr=0.5306
# 2025-04-24 00:03:28,665 - INFO - Epoch 009 | loss=49.070 val_MCC=0.7196 thr=0.5317
# 2025-04-24 00:03:38,746 - INFO - Epoch 010 | loss=47.207 val_MCC=0.7196 thr=0.5402
# 2025-04-24 00:03:48,370 - INFO - Epoch 011 | loss=46.976 val_MCC=0.6655 thr=0.5302
# 2025-04-24 00:03:59,302 - INFO - Training completed in 123.3s best_MCC=0.7536
# [I 2025-04-24 00:03:59,606] Trial 3 finished with value: 0.753592220347252 and parameters: {'h_dim': 128, 'z_dim': 64, 'n_layers': 3, 'dropout': 0.2123738038749523, 'act_fn': 'leakyrelu', 'lr': 0.00014096175149815865, 'beta_KL': 0.9133995846860972, 'gamma_CE': 0.2073644517790503, 'lam_rec': 0.1987156815341724, 'lam_lat': 0.0044247858558742244, 'eta_fuse': 0.8154614284548342, 'k_rule': 3, 'tau': 0.7290071680409873}. Best is trial 0 with value: 0.8329931278350429.
# 2025-04-24 00:03:59,647 - INFO - Loading graphs from \grafos\grafos_mst.pkl
# 2025-04-24 00:04:09,087 - INFO - Total loaded: 4304
# 2025-04-24 00:04:09,090 - INFO - Training set: 200 normals
# 2025-04-24 00:04:09,094 - INFO - Test set: 2000 graphs (58 normals)
# 2025-04-24 00:04:09,096 - INFO - Validation set: 1400 graphs (40 normals)
# Graphs loaded from \grafos\grafos_mst.pkl
# 2025-04-24 00:04:12,432 - INFO - Partitioning done: train=200, test=2000, valid=1400
# 2025-04-24 00:04:12,453 - INFO - Descriptor 'num_nodes': mean = 3.9950, std = 1.9300
# 2025-04-24 00:04:12,454 - INFO - Descriptor 'num_edges': mean = 2.1400, std = 1.2167
# 2025-04-24 00:04:12,455 - INFO - Descriptor 'density': mean = 0.5377, std = 0.3420
# 2025-04-24 00:04:12,455 - INFO - Descriptor 'average_degree': mean = 1.0490, std = 0.1078
# 2025-04-24 00:04:12,456 - INFO - Descriptor 'average_clustering': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,456 - INFO - Descriptor 'diameter': mean = nan, std = nan
# 2025-04-24 00:04:12,456 - INFO - Descriptor 'average_shortest_path_length': mean = nan, std = nan
# 2025-04-24 00:04:12,457 - INFO - Descriptor 'spectral_gap': mean = 1.8028, std = 0.4113
# 2025-04-24 00:04:12,457 - INFO - Descriptor 'data_mean_Src_Port': mean = 15340.2390, std = 12905.8309
# 2025-04-24 00:04:12,457 - INFO - Descriptor 'data_mean_Dst_Port': mean = 42395.8523, std = 12929.6631
# 2025-04-24 00:04:12,458 - INFO - Descriptor 'data_mean_Protocol': mean = 6.0225, std = 0.1122
# 2025-04-24 00:04:12,458 - INFO - Descriptor 'data_mean_Flow_Duration': mean = 336.0314, std = 36.6909
# 2025-04-24 00:04:12,458 - INFO - Descriptor 'data_mean_Tot_Fwd_Pkts': mean = 1.2074, std = 0.2752
# 2025-04-24 00:04:12,459 - INFO - Descriptor 'data_mean_TotLen_Fwd_Pkts': mean = 1128.5784, std = 534.7207
# 2025-04-24 00:04:12,459 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Min': mean = 361.6088, std = 246.5826
# 2025-04-24 00:04:12,459 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Std': mean = 193.1974, std = 109.6026
# 2025-04-24 00:04:12,460 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Max': mean = 878.2470, std = 187.7843
# 2025-04-24 00:04:12,460 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Min': mean = 770.4363, std = 220.7591
# 2025-04-24 00:04:12,460 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Std': mean = 66.9040, std = 82.7757
# 2025-04-24 00:04:12,461 - INFO - Descriptor 'data_mean_Flow_Byts/s': mean = 7731723.4451, std = 2106485.3160
# 2025-04-24 00:04:12,461 - INFO - Descriptor 'data_mean_Flow_Pkts/s': mean = 10639.5583, std = 1831.1583
# 2025-04-24 00:04:12,461 - INFO - Descriptor 'data_mean_Flow_IAT_Mean': mean = 211.9494, std = 28.7064
# 2025-04-24 00:04:12,462 - INFO - Descriptor 'data_mean_Flow_IAT_Std': mean = 42.8096, std = 10.2620
# 2025-04-24 00:04:12,462 - INFO - Descriptor 'data_mean_Flow_IAT_Max': mean = 250.2938, std = 30.0008
# 2025-04-24 00:04:12,462 - INFO - Descriptor 'data_mean_Flow_IAT_Min': mean = 181.3539, std = 28.9614
# 2025-04-24 00:04:12,463 - INFO - Descriptor 'data_mean_Fwd_IAT_Tot': mean = 84.0944, std = 25.0187
# 2025-04-24 00:04:12,463 - INFO - Descriptor 'data_mean_Fwd_IAT_Mean': mean = 54.7514, std = 16.9477
# 2025-04-24 00:04:12,463 - INFO - Descriptor 'data_mean_Fwd_IAT_Std': mean = 10.6888, std = 4.7656
# 2025-04-24 00:04:12,464 - INFO - Descriptor 'data_mean_Fwd_IAT_Max': mean = 63.1206, std = 18.0882
# 2025-04-24 00:04:12,464 - INFO - Descriptor 'data_mean_Fwd_IAT_Min': mean = 47.1140, std = 16.4286
# 2025-04-24 00:04:12,464 - INFO - Descriptor 'data_mean_Bwd_IAT_Tot': mean = 138.0916, std = 43.0785
# 2025-04-24 00:04:12,465 - INFO - Descriptor 'data_mean_Bwd_IAT_Mean': mean = 95.8374, std = 26.1567
# 2025-04-24 00:04:12,465 - INFO - Descriptor 'data_mean_Bwd_IAT_Std': mean = 18.0133, std = 8.1246
# 2025-04-24 00:04:12,465 - INFO - Descriptor 'data_mean_Bwd_IAT_Max': mean = 112.2262, std = 31.2669
# 2025-04-24 00:04:12,466 - INFO - Descriptor 'data_mean_Bwd_IAT_Min': mean = 83.6670, std = 22.9412
# 2025-04-24 00:04:12,466 - INFO - Descriptor 'data_mean_Fwd_PSH_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,466 - INFO - Descriptor 'data_mean_Bwd_PSH_Flags': mean = 0.0562, std = 0.0792
# 2025-04-24 00:04:12,468 - INFO - Descriptor 'data_mean_Fwd_URG_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,469 - INFO - Descriptor 'data_mean_Fwd_Header_Len': mean = 38.3877, std = 8.9023
# 2025-04-24 00:04:12,469 - INFO - Descriptor 'data_mean_Bwd_Header_Len': mean = 53.7464, std = 9.4915
# 2025-04-24 00:04:12,469 - INFO - Descriptor 'data_mean_Fwd_Pkts/s': mean = 4165.8514, std = 1326.6419
# 2025-04-24 00:04:12,470 - INFO - Descriptor 'data_mean_Bwd_Pkts/s': mean = 6473.7069, std = 1297.7102
# 2025-04-24 00:04:12,470 - INFO - Descriptor 'data_mean_Pkt_Len_Min': mean = 401.8654, std = 234.6780
# 2025-04-24 00:04:12,470 - INFO - Descriptor 'data_mean_Pkt_Len_Max': mean = 901.3069, std = 187.0834
# 2025-04-24 00:04:12,471 - INFO - Descriptor 'data_mean_Pkt_Len_Mean': mean = 763.0043, std = 183.5884
# 2025-04-24 00:04:12,471 - INFO - Descriptor 'data_mean_Pkt_Len_Std': mean = 247.8380, std = 80.6116
# 2025-04-24 00:04:12,471 - INFO - Descriptor 'data_mean_Pkt_Len_Var': mean = 165083.5364, std = 59660.9934
# 2025-04-24 00:04:12,472 - INFO - Descriptor 'data_mean_FIN_Flag_Cnt': mean = 0.0005, std = 0.0038
# 2025-04-24 00:04:12,472 - INFO - Descriptor 'data_mean_SYN_Flag_Cnt': mean = 0.0005, std = 0.0038
# 2025-04-24 00:04:12,472 - INFO - Descriptor 'data_mean_RST_Flag_Cnt': mean = 0.0002, std = 0.0020
# 2025-04-24 00:04:12,473 - INFO - Descriptor 'data_mean_ACK_Flag_Cnt': mean = 0.9961, std = 0.0105
# 2025-04-24 00:04:12,473 - INFO - Descriptor 'data_mean_URG_Flag_Cnt': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,473 - INFO - Descriptor 'data_mean_CWE_Flag_Count': mean = 0.0002, std = 0.0018
# 2025-04-24 00:04:12,474 - INFO - Descriptor 'data_mean_ECE_Flag_Cnt': mean = 0.0005, std = 0.0037
# 2025-04-24 00:04:12,474 - INFO - Descriptor 'data_mean_Down/Up_Ratio': mean = 0.2813, std = 0.1271
# 2025-04-24 00:04:12,474 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Avg': mean = 548.4981, std = 259.1223
# 2025-04-24 00:04:12,475 - INFO - Descriptor 'data_mean_Fwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,475 - INFO - Descriptor 'data_mean_Fwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,475 - INFO - Descriptor 'data_mean_Fwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,476 - INFO - Descriptor 'data_mean_Bwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,476 - INFO - Descriptor 'data_mean_Bwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,476 - INFO - Descriptor 'data_mean_Bwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,477 - INFO - Descriptor 'data_mean_Subflow_Bwd_Pkts': mean = 1.6926, std = 0.2926
# 2025-04-24 00:04:12,477 - INFO - Descriptor 'data_mean_Subflow_Bwd_Byts': mean = 1077.6663, std = 488.7494
# 2025-04-24 00:04:12,477 - INFO - Descriptor 'data_mean_Init_Fwd_Win_Byts': mean = -1.0000, std = 0.0000
# 2025-04-24 00:04:12,478 - INFO - Descriptor 'data_mean_Init_Bwd_Win_Byts': mean = 13244.5121, std = 4116.0099
# 2025-04-24 00:04:12,478 - INFO - Descriptor 'data_mean_Fwd_Act_Data_Pkts': mean = 1.0964, std = 0.4518
# 2025-04-24 00:04:12,478 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,479 - INFO - Descriptor 'data_mean_Active_Mean': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,479 - INFO - Descriptor 'data_mean_Active_Std': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,479 - INFO - Descriptor 'data_mean_Active_Max': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,480 - INFO - Descriptor 'data_mean_Active_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:04:12,480 - INFO - Descriptor 'data_mean_Idle_Mean': mean = 210.7935, std = 31.0922
# 2025-04-24 00:04:12,481 - INFO - Descriptor 'data_mean_Idle_Std': mean = 42.7966, std = 10.2679
# 2025-04-24 00:04:12,481 - INFO - Descriptor 'data_mean_Idle_Min': mean = 180.2040, std = 30.9189
# 2025-04-24 00:04:22,002 - INFO - Epoch 001 | loss=28.224 val_MCC=0.8629 thr=0.5280
# 2025-04-24 00:04:28,759 - INFO - Epoch 002 | loss=16.822 val_MCC=0.8629 thr=0.4483
# 2025-04-24 00:04:35,459 - INFO - Epoch 003 | loss=11.518 val_MCC=0.8629 thr=0.4074
# 2025-04-24 00:04:42,146 - INFO - Epoch 004 | loss=9.660 val_MCC=0.8918 thr=0.4051
# 2025-04-24 00:04:48,379 - INFO - Epoch 005 | loss=9.480 val_MCC=0.8774 thr=0.3872
# 2025-04-24 00:04:54,611 - INFO - Epoch 006 | loss=9.123 val_MCC=0.8774 thr=0.3847
# 2025-04-24 00:05:01,127 - INFO - Epoch 007 | loss=9.593 val_MCC=0.8480 thr=0.3798
# 2025-04-24 00:05:07,468 - INFO - Epoch 008 | loss=8.640 val_MCC=0.8631 thr=0.3817
# 2025-04-24 00:05:13,880 - INFO - Epoch 009 | loss=8.625 val_MCC=0.8629 thr=0.3744
# 2025-04-24 00:05:19,816 - INFO - Epoch 010 | loss=8.631 val_MCC=0.8629 thr=0.3712
# 2025-04-24 00:05:26,124 - INFO - Epoch 011 | loss=8.833 val_MCC=0.8480 thr=0.3700
# 2025-04-24 00:05:32,518 - INFO - Epoch 012 | loss=8.794 val_MCC=0.8480 thr=0.3706
# 2025-04-24 00:05:38,872 - INFO - Epoch 013 | loss=8.667 val_MCC=0.8629 thr=0.3691
# 2025-04-24 00:05:45,234 - INFO - Training completed in 89.6s best_MCC=0.8918
# [I 2025-04-24 00:05:45,540] Trial 4 finished with value: 0.8918080720799182 and parameters: {'h_dim': 32, 'z_dim': 32, 'n_layers': 2, 'dropout': 0.12542334011440948, 'act_fn': 'leakyrelu', 'lr': 0.0018841476921545091, 'beta_KL': 0.45881565491609727, 'gamma_CE': 0.026100256506134758, 'lam_rec': 0.1195942459383017, 'lam_lat': 0.6279448147256365, 'eta_fuse': 0.7607850486168974, 'k_rule': 2, 'tau': 0.770967179954561}. Best is trial 4 with value: 0.8918080720799182.
# 2025-04-24 00:05:45,586 - INFO - Loading graphs from \grafos\grafos_mst.pkl
# 2025-04-24 00:05:55,397 - INFO - Total loaded: 4304
# ...
# 2025-04-24 00:31:47,459 - INFO - Descriptor 'data_mean_Bwd_IAT_Mean': mean = 96.6710, std = 26.9233
# 2025-04-24 00:31:47,459 - INFO - Descriptor 'data_mean_Bwd_IAT_Std': mean = 18.4914, std = 7.6126
# 2025-04-24 00:31:47,459 - INFO - Descriptor 'data_mean_Bwd_IAT_Max': mean = 113.5635, std = 31.5918
# 2025-04-24 00:31:47,460 - INFO - Descriptor 'data_mean_Bwd_IAT_Min': mean = 84.1992, std = 23.9859
# 2025-04-24 00:31:47,460 - INFO - Descriptor 'data_mean_Fwd_PSH_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,460 - INFO - Descriptor 'data_mean_Bwd_PSH_Flags': mean = 0.0519, std = 0.0410
# 2025-04-24 00:31:47,461 - INFO - Descriptor 'data_mean_Fwd_URG_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,461 - INFO - Descriptor 'data_mean_Fwd_Header_Len': mean = 38.6561, std = 9.3168
# 2025-04-24 00:31:47,461 - INFO - Descriptor 'data_mean_Bwd_Header_Len': mean = 54.1665, std = 9.1012
# 2025-04-24 00:31:47,462 - INFO - Descriptor 'data_mean_Fwd_Pkts/s': mean = 4107.6587, std = 1132.1965
# 2025-04-24 00:31:47,462 - INFO - Descriptor 'data_mean_Bwd_Pkts/s': mean = 6450.1713, std = 1101.5920
# 2025-04-24 00:31:47,462 - INFO - Descriptor 'data_mean_Pkt_Len_Min': mean = 404.3637, std = 245.1473
# 2025-04-24 00:31:47,463 - INFO - Descriptor 'data_mean_Pkt_Len_Max': mean = 901.8664, std = 169.7393
# 2025-04-24 00:31:47,463 - INFO - Descriptor 'data_mean_Pkt_Len_Mean': mean = 764.5167, std = 174.2882
# 2025-04-24 00:31:47,463 - INFO - Descriptor 'data_mean_Pkt_Len_Std': mean = 246.1419, std = 74.1820
# 2025-04-24 00:31:47,464 - INFO - Descriptor 'data_mean_Pkt_Len_Var': mean = 163236.1710, std = 55193.3145
# 2025-04-24 00:31:47,464 - INFO - Descriptor 'data_mean_FIN_Flag_Cnt': mean = 0.0007, std = 0.0040
# 2025-04-24 00:31:47,464 - INFO - Descriptor 'data_mean_SYN_Flag_Cnt': mean = 0.0005, std = 0.0039
# 2025-04-24 00:31:47,464 - INFO - Descriptor 'data_mean_RST_Flag_Cnt': mean = 0.0003, std = 0.0021
# 2025-04-24 00:31:47,465 - INFO - Descriptor 'data_mean_ACK_Flag_Cnt': mean = 0.9956, std = 0.0138
# 2025-04-24 00:31:47,465 - INFO - Descriptor 'data_mean_URG_Flag_Cnt': mean = 0.0001, std = 0.0007
# 2025-04-24 00:31:47,465 - INFO - Descriptor 'data_mean_CWE_Flag_Count': mean = 0.0003, std = 0.0020
# 2025-04-24 00:31:47,466 - INFO - Descriptor 'data_mean_ECE_Flag_Cnt': mean = 0.0005, std = 0.0039
# 2025-04-24 00:31:47,466 - INFO - Descriptor 'data_mean_Down/Up_Ratio': mean = 0.2703, std = 0.1098
# 2025-04-24 00:31:47,466 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Avg': mean = 555.8321, std = 262.8154
# 2025-04-24 00:31:47,467 - INFO - Descriptor 'data_mean_Fwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,467 - INFO - Descriptor 'data_mean_Fwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,467 - INFO - Descriptor 'data_mean_Fwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,468 - INFO - Descriptor 'data_mean_Bwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,468 - INFO - Descriptor 'data_mean_Bwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,468 - INFO - Descriptor 'data_mean_Bwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,469 - INFO - Descriptor 'data_mean_Subflow_Bwd_Pkts': mean = 1.7060, std = 0.2835
# 2025-04-24 00:31:47,469 - INFO - Descriptor 'data_mean_Subflow_Bwd_Byts': mean = 1070.5478, std = 476.9041
# 2025-04-24 00:31:47,469 - INFO - Descriptor 'data_mean_Init_Fwd_Win_Byts': mean = -1.0000, std = 0.0000
# 2025-04-24 00:31:47,469 - INFO - Descriptor 'data_mean_Init_Bwd_Win_Byts': mean = 13384.3183, std = 3497.7687
# 2025-04-24 00:31:47,470 - INFO - Descriptor 'data_mean_Fwd_Act_Data_Pkts': mean = 1.1219, std = 0.4473
# 2025-04-24 00:31:47,470 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,470 - INFO - Descriptor 'data_mean_Active_Mean': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,471 - INFO - Descriptor 'data_mean_Active_Std': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,471 - INFO - Descriptor 'data_mean_Active_Max': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,471 - INFO - Descriptor 'data_mean_Active_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:31:47,472 - INFO - Descriptor 'data_mean_Idle_Mean': mean = 210.7783, std = 26.2134
# 2025-04-24 00:31:47,472 - INFO - Descriptor 'data_mean_Idle_Std': mean = 43.5067, std = 9.0698
# 2025-04-24 00:31:47,472 - INFO - Descriptor 'data_mean_Idle_Min': mean = 179.6840, std = 27.4551
# 2025-04-24 00:32:01,143 - INFO - Epoch 001 | loss=13.980 val_MCC=0.9060 thr=0.9078
# 2025-04-24 00:32:10,527 - INFO - Epoch 002 | loss=13.547 val_MCC=0.9060 thr=0.9078
# 2025-04-24 00:32:21,323 - INFO - Epoch 003 | loss=13.679 val_MCC=0.9060 thr=0.9065
# 2025-04-24 00:32:31,967 - INFO - Epoch 004 | loss=13.660 val_MCC=0.9060 thr=0.9070
# 2025-04-24 00:32:42,653 - INFO - Epoch 005 | loss=14.680 val_MCC=0.9060 thr=0.9060
# 2025-04-24 00:32:53,568 - INFO - Epoch 006 | loss=12.710 val_MCC=0.9060 thr=0.9062
# 2025-04-24 00:33:04,706 - INFO - Epoch 007 | loss=13.855 val_MCC=0.9060 thr=0.9061
# 2025-04-24 00:33:15,936 - INFO - Epoch 008 | loss=14.089 val_MCC=0.9060 thr=0.9055
# 2025-04-24 00:33:25,919 - INFO - Epoch 009 | loss=13.694 val_MCC=0.9199 thr=0.9057
# 2025-04-24 00:33:37,433 - INFO - Epoch 010 | loss=13.232 val_MCC=0.9199 thr=0.9050
# 2025-04-24 00:33:47,372 - INFO - Epoch 011 | loss=14.045 val_MCC=0.9199 thr=0.9058
# 2025-04-24 00:33:56,393 - INFO - Epoch 012 | loss=13.387 val_MCC=0.9199 thr=0.9063
# 2025-04-24 00:34:06,405 - INFO - Epoch 013 | loss=13.119 val_MCC=0.9062 thr=0.9055
# 2025-04-24 00:34:16,605 - INFO - Epoch 014 | loss=13.068 val_MCC=0.9199 thr=0.9056
# 2025-04-24 00:34:27,233 - INFO - Epoch 015 | loss=13.663 val_MCC=0.9060 thr=0.9040
# 2025-04-24 00:34:38,336 - INFO - Epoch 016 | loss=14.359 val_MCC=0.9199 thr=0.9035
# 2025-04-24 00:34:48,650 - INFO - Epoch 017 | loss=13.762 val_MCC=0.9199 thr=0.9046
# 2025-04-24 00:34:58,527 - INFO - Epoch 018 | loss=14.438 val_MCC=0.9060 thr=0.9042
# [I 2025-04-24 00:35:08,845] Trial 19 pruned.
# 2025-04-24 00:35:08,847 - INFO - Loading graphs from \grafos\grafos_mst.pkl
# === Resultados Optuna ===
# Best M​CC:     0.961937531746931
# Best params:  {'h_dim': 32, 'z_dim': 16, 'n_layers': 3, 'dropout': 0.2770713002465045, 'act_fn': 'relu', 'lr': 0.0037643083521274566, 'beta_KL': 0.04535094634779837, 'gamma_CE': 0.015043838978395768, 'lam_rec': 0.43729139171842235, 'lam_lat': 0.31045483654546724, 'eta_fuse': 0.028478291139971468, 'k_rule': 3, 'tau': 0.9168184602315099}
# Mejores params: {'h_dim': 32, 'z_dim': 16, 'n_layers': 3, 'dropout': 0.2770713002465045, 'act_fn': 'relu', 'lr': 0.0037643083521274566, 'beta_KL': 0.04535094634779837, 'gamma_CE': 0.015043838978395768, 'lam_rec': 0.43729139171842235, 'lam_lat': 0.31045483654546724, 'eta_fuse': 0.028478291139971468, 'k_rule': 3, 'tau': 0.9168184602315099}
# 2025-04-24 00:35:18,756 - INFO - Total loaded: 4304
# 2025-04-24 00:35:18,759 - INFO - Training set: 200 normals
# 2025-04-24 00:35:18,762 - INFO - Test set: 1500 graphs (68 normals)
# 2025-04-24 00:35:18,763 - INFO - Validation set: 1500 graphs (30 normals)
# 2025-04-24 00:35:22,084 - INFO - Partitioning done: train=200, test=1500, valid=1500
# Graphs loaded from \grafos\grafos_mst.pkl
# 2025-04-24 00:35:22,108 - INFO - Descriptor 'num_nodes': mean = 4.2150, std = 2.0122
# 2025-04-24 00:35:22,109 - INFO - Descriptor 'num_edges': mean = 2.2700, std = 1.2717
# 2025-04-24 00:35:22,110 - INFO - Descriptor 'density': mean = 0.5122, std = 0.3434
# 2025-04-24 00:35:22,110 - INFO - Descriptor 'average_degree': mean = 1.0531, std = 0.1108
# 2025-04-24 00:35:22,110 - INFO - Descriptor 'average_clustering': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,111 - INFO - Descriptor 'diameter': mean = nan, std = nan
# 2025-04-24 00:35:22,111 - INFO - Descriptor 'average_shortest_path_length': mean = nan, std = nan
# 2025-04-24 00:35:22,111 - INFO - Descriptor 'spectral_gap': mean = 1.7797, std = 0.4332
# 2025-04-24 00:35:22,112 - INFO - Descriptor 'data_mean_Src_Port': mean = 14830.1290, std = 12364.5429
# 2025-04-24 00:35:22,112 - INFO - Descriptor 'data_mean_Dst_Port': mean = 42925.0088, std = 12381.6448
# 2025-04-24 00:35:22,112 - INFO - Descriptor 'data_mean_Protocol': mean = 6.0313, std = 0.1232
# 2025-04-24 00:35:22,113 - INFO - Descriptor 'data_mean_Flow_Duration': mean = 336.3013, std = 35.0237
# 2025-04-24 00:35:22,113 - INFO - Descriptor 'data_mean_Tot_Fwd_Pkts': mean = 1.2171, std = 0.2845
# 2025-04-24 00:35:22,113 - INFO - Descriptor 'data_mean_TotLen_Fwd_Pkts': mean = 1157.3669, std = 526.3203
# 2025-04-24 00:35:22,114 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Min': mean = 370.1343, std = 253.9560
# 2025-04-24 00:35:22,114 - INFO - Descriptor 'data_mean_Fwd_Pkt_Len_Std': mean = 195.5451, std = 109.3555
# 2025-04-24 00:35:22,114 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Max': mean = 881.2679, std = 175.6649
# 2025-04-24 00:35:22,115 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Min': mean = 783.8483, std = 217.3079
# 2025-04-24 00:35:22,115 - INFO - Descriptor 'data_mean_Bwd_Pkt_Len_Std': mean = 60.6285, std = 78.6667
# 2025-04-24 00:35:22,115 - INFO - Descriptor 'data_mean_Flow_Byts/s': mean = 7883085.1343, std = 2366553.2229
# 2025-04-24 00:35:22,115 - INFO - Descriptor 'data_mean_Flow_Pkts/s': mean = 10672.4040, std = 1576.0165
# 2025-04-24 00:35:22,116 - INFO - Descriptor 'data_mean_Flow_IAT_Mean': mean = 210.2337, std = 26.9937
# 2025-04-24 00:35:22,116 - INFO - Descriptor 'data_mean_Flow_IAT_Std': mean = 43.1677, std = 11.2927
# 2025-04-24 00:35:22,116 - INFO - Descriptor 'data_mean_Flow_IAT_Max': mean = 248.8274, std = 28.0821
# 2025-04-24 00:35:22,117 - INFO - Descriptor 'data_mean_Flow_IAT_Min': mean = 179.3484, std = 27.9765
# 2025-04-24 00:35:22,117 - INFO - Descriptor 'data_mean_Fwd_IAT_Tot': mean = 84.7622, std = 24.2411
# 2025-04-24 00:35:22,117 - INFO - Descriptor 'data_mean_Fwd_IAT_Mean': mean = 55.1398, std = 16.3493
# 2025-04-24 00:35:22,118 - INFO - Descriptor 'data_mean_Fwd_IAT_Std': mean = 10.7128, std = 4.9144
# 2025-04-24 00:35:22,118 - INFO - Descriptor 'data_mean_Fwd_IAT_Max': mean = 63.5423, std = 17.5028
# 2025-04-24 00:35:22,118 - INFO - Descriptor 'data_mean_Fwd_IAT_Min': mean = 47.4930, std = 15.9104
# 2025-04-24 00:35:22,119 - INFO - Descriptor 'data_mean_Bwd_IAT_Tot': mean = 139.5179, std = 49.2082
# 2025-04-24 00:35:22,119 - INFO - Descriptor 'data_mean_Bwd_IAT_Mean': mean = 96.2832, std = 26.7613
# 2025-04-24 00:35:22,119 - INFO - Descriptor 'data_mean_Bwd_IAT_Std': mean = 18.3472, std = 11.0675
# 2025-04-24 00:35:22,120 - INFO - Descriptor 'data_mean_Bwd_IAT_Max': mean = 112.9343, std = 32.8392
# 2025-04-24 00:35:22,120 - INFO - Descriptor 'data_mean_Bwd_IAT_Min': mean = 83.8783, std = 23.3298
# 2025-04-24 00:35:22,120 - INFO - Descriptor 'data_mean_Fwd_PSH_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,121 - INFO - Descriptor 'data_mean_Bwd_PSH_Flags': mean = 0.0543, std = 0.0505
# 2025-04-24 00:35:22,121 - INFO - Descriptor 'data_mean_Fwd_URG_Flags': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,121 - INFO - Descriptor 'data_mean_Fwd_Header_Len': mean = 38.7008, std = 9.1124
# 2025-04-24 00:35:22,122 - INFO - Descriptor 'data_mean_Bwd_Header_Len': mean = 54.1068, std = 11.5064
# 2025-04-24 00:35:22,122 - INFO - Descriptor 'data_mean_Fwd_Pkts/s': mean = 4202.0807, std = 1284.0871
# 2025-04-24 00:35:22,122 - INFO - Descriptor 'data_mean_Bwd_Pkts/s': mean = 6470.3233, std = 1168.4413
# 2025-04-24 00:35:22,122 - INFO - Descriptor 'data_mean_Pkt_Len_Min': mean = 408.5428, std = 246.4431
# 2025-04-24 00:35:22,123 - INFO - Descriptor 'data_mean_Pkt_Len_Max': mean = 905.1833, std = 175.1856
# 2025-04-24 00:35:22,123 - INFO - Descriptor 'data_mean_Pkt_Len_Mean': mean = 767.1510, std = 179.2819
# 2025-04-24 00:35:22,123 - INFO - Descriptor 'data_mean_Pkt_Len_Std': mean = 246.5530, std = 79.8747
# 2025-04-24 00:35:22,124 - INFO - Descriptor 'data_mean_Pkt_Len_Var': mean = 163134.2053, std = 58834.0095
# 2025-04-24 00:35:22,124 - INFO - Descriptor 'data_mean_FIN_Flag_Cnt': mean = 0.0006, std = 0.0038
# 2025-04-24 00:35:22,124 - INFO - Descriptor 'data_mean_SYN_Flag_Cnt': mean = 0.0007, std = 0.0040
# 2025-04-24 00:35:22,125 - INFO - Descriptor 'data_mean_RST_Flag_Cnt': mean = 0.0003, std = 0.0022
# 2025-04-24 00:35:22,125 - INFO - Descriptor 'data_mean_ACK_Flag_Cnt': mean = 0.9956, std = 0.0116
# 2025-04-24 00:35:22,125 - INFO - Descriptor 'data_mean_URG_Flag_Cnt': mean = 0.0001, std = 0.0007
# 2025-04-24 00:35:22,126 - INFO - Descriptor 'data_mean_CWE_Flag_Count': mean = 0.0002, std = 0.0019
# 2025-04-24 00:35:22,126 - INFO - Descriptor 'data_mean_ECE_Flag_Cnt': mean = 0.0006, std = 0.0039
# 2025-04-24 00:35:22,126 - INFO - Descriptor 'data_mean_Down/Up_Ratio': mean = 0.2742, std = 0.1160
# 2025-04-24 00:35:22,126 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Avg': mean = 558.9430, std = 252.4384
# 2025-04-24 00:35:22,127 - INFO - Descriptor 'data_mean_Fwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,127 - INFO - Descriptor 'data_mean_Fwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,127 - INFO - Descriptor 'data_mean_Fwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,128 - INFO - Descriptor 'data_mean_Bwd_Byts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,128 - INFO - Descriptor 'data_mean_Bwd_Pkts/b_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,128 - INFO - Descriptor 'data_mean_Bwd_Blk_Rate_Avg': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,128 - INFO - Descriptor 'data_mean_Subflow_Bwd_Pkts': mean = 1.7025, std = 0.3586
# 2025-04-24 00:35:22,129 - INFO - Descriptor 'data_mean_Subflow_Bwd_Byts': mean = 1072.4946, std = 467.8355
# 2025-04-24 00:35:22,131 - INFO - Descriptor 'data_mean_Init_Fwd_Win_Byts': mean = -1.0000, std = 0.0000
# 2025-04-24 00:35:22,132 - INFO - Descriptor 'data_mean_Init_Bwd_Win_Byts': mean = 12976.7581, std = 3640.0830
# 2025-04-24 00:35:22,132 - INFO - Descriptor 'data_mean_Fwd_Act_Data_Pkts': mean = 1.1231, std = 0.4319
# 2025-04-24 00:35:22,132 - INFO - Descriptor 'data_mean_Fwd_Seg_Size_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,132 - INFO - Descriptor 'data_mean_Active_Mean': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,133 - INFO - Descriptor 'data_mean_Active_Std': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,133 - INFO - Descriptor 'data_mean_Active_Max': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,133 - INFO - Descriptor 'data_mean_Active_Min': mean = 0.0000, std = 0.0000
# 2025-04-24 00:35:22,134 - INFO - Descriptor 'data_mean_Idle_Mean': mean = 209.3804, std = 27.0614
# 2025-04-24 00:35:22,134 - INFO - Descriptor 'data_mean_Idle_Std': mean = 43.1350, std = 11.3138
# 2025-04-24 00:35:22,134 - INFO - Descriptor 'data_mean_Idle_Min': mean = 178.5158, std = 28.0199
# 2025-04-24 00:35:47,575 - INFO - Epoch 001 | loss=151.177 val_MCC=0.9661 thr=0.9764
# 2025-04-24 00:36:09,542 - INFO - Epoch 002 | loss=142.451 val_MCC=0.9661 thr=0.9764
# 2025-04-24 00:36:28,673 - INFO - Epoch 003 | loss=146.828 val_MCC=0.9661 thr=0.9766
# 2025-04-24 00:36:46,695 - INFO - Epoch 004 | loss=142.334 val_MCC=0.9661 thr=0.9766
# 2025-04-24 00:37:04,511 - INFO - Epoch 005 | loss=141.424 val_MCC=0.9661 thr=0.9769
# 2025-04-24 00:37:25,294 - INFO - Epoch 006 | loss=142.035 val_MCC=0.9661 thr=0.9769
# 2025-04-24 00:37:44,340 - INFO - Epoch 007 | loss=143.724 val_MCC=0.9661 thr=0.9769
# 2025-04-24 00:38:02,943 - INFO - Epoch 008 | loss=146.557 val_MCC=0.9661 thr=0.9768
# 2025-04-24 00:38:21,347 - INFO - Epoch 009 | loss=143.336 val_MCC=0.9661 thr=0.9769
# 2025-04-24 00:38:39,810 - INFO - Epoch 010 | loss=146.022 val_MCC=0.9661 thr=0.9769
# 2025-04-24 00:38:59,486 - INFO - Training completed in 214.1s best_MCC=0.9661
# >>> TEST MCC: 0.9661389485159884
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal     1.0000    0.9367    0.9673        79
#      Anomaly     0.9965    1.0000    0.9982      1421
#
#     accuracy                         0.9967      1500
#    macro avg     0.9982    0.9684    0.9828      1500
# weighted avg     0.9967    0.9967    0.9966      1500
#
#
# Confusion Matrix:
#  [[  74    5]
#  [   0 1421]]
